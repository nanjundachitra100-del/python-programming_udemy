# %%
import numpy as np

lst_marks = [30, 45, 67, 57, 48, 39, 57, 49, 67]

minimum, Q1, median, Q3, maximum = np.quantile(
    lst_marks,
    [0, 0.25, 0.50, 0.75, 1]
)
#Common quantiles
#Quantile (q)	Meaning
#0	Minimum value
#0.25	First Quartile (Q1)
0#.50	Median (Q2)
#0.75	Third Quartile (Q3)
#1 is Maximum value

print("Minimum :", minimum)
print("Q1      :", Q1)
print("Median  :", median)
print("Q3      :", Q3)
print("Maximum :", maximum)

IQR=Q3-Q1
print("IQR:",IQR)

lower_fence=Q1-1.5*(IQR)
upper_fence=Q3+1.5*(IQR)

print("lower_fence:",lower_fence)
print("upper_fence:",upper_fence)
#anything less than lower_fence value and greater than the upper_fence value is considered as the outlier
# Out:
# Minimum : 30.0
# Q1      : 45.0
# Median  : 49.0
# Q3      : 57.0
# Maximum : 67.0
# IQR: 12.0
# lower_fence: 27.0
# upper_fence: 75.0

# %%
import seaborn as sns
sns.boxplot(lst_marks)#without outlier
# Out:
# <Axes: >

# %%
#with outlier
lst_marks=[-100,2,45,78,56,47,36,48,59,79,68,200,4000,6000]
sns.boxplot(lst_marks)
# Out:
# <Axes: >
