# %%
num1=int(input("Enter the number:"))
num2=int(input("Enter the number:"))
operation=input("Enter the operation + ,- ,* ,/ ,%: ")

if(operation=='+'):
    print(num1+num2)
elif(operation=='-'):
    print(num1-num2)
elif(operation=='*'):
    print(num1*num2)
elif(operation=='/'):
    print(num1/num2)
elif(operation=='%'):
    print(num1%num2)
else:
    print("Invalid operation or number entered")
# Out:
# Select the operation + ,- ,* ,/ ,%
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       2 num2=int(input("Enter the number:"))
#       3 operations='+','-','*','/','%'
#       4 print("Select the operation + ,- ,* ,/ ,%")
#       5
# ----> 6 if(operation=='+'):
#       7     print(num1+num2)
#       8 elif(operation=='-'):
#       9     print(num1-num2)
#
# NameError: name 'operation' is not defined
