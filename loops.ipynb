# %%
n=10
sum=0
for i in range(11):
    sum += i
    print("sum is:", sum)
# Out:
# sum is: 0
# sum is: 1
# sum is: 3
# sum is: 6
# sum is: 10
# sum is: 15
# sum is: 21
# sum is: 28
# sum is: 36
# sum is: 45
# sum is: 55

# %%
for i in range(1,11):
    if(i>1):
        for j in range(2,i):
            if(i%j==0):
                break
        else:
            print(i)
# Out:
# 2
# 3
# 5
# 7

# %%
#check if the number is positive or negative and also check even or odd
n=int(input("Enter the number:"))

if(n>0):
    print("the number is positive")
    if(n%2==0):
        print("The number is even and positive")
    else:
        print("The number is odd and positive")
else:
    print("The number is neagtive")
# Out:
# the number is positive
# The number is even and positive

# %%
n=5
for i in range(1,n+1):
    for j in range(i,i+1):
        print("**,"end=" ")
print("\n")
# Out:
# *
# *
# *
# *
# *
