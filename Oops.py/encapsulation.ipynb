# %%
#self.name=name(public variable)
#self.__name=name(private variable)

class ATM:
    def __init__(self,balance):
        self.balance=balance

CBI=ATM(1000)
CBI.balance=100000
#here anyone can give input which might cause claughs
print(CBI.balance)
# Out:
# 100000

# %%
class ATM:
    def __init__ (self,balance):
        self.__balance=balance

    def check_balance(self):
        print(self.__balance)

CBI=ATM(1000)
print(CBI.balance)# this gives erroe so we need to use getters and setters to acces
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 9
#       5     def check_balance(self):
#       6         print(self.__balance)
#       7
#       8 CBI=ATM(1000)
# ----> 9 print(CBI.balance)
#
# AttributeError: 'ATM' object has no attribute 'balance'

# %%
#using getters
class ATM:
    def __init__(self,balance):
        self.__balance=balance

    def get_balance(self):
        return self.get_balance
    
bank1=ATM(100000)
print(bank1.get_balance())
# Out:
# <bound method ATM.get_balance of <__main__.ATM object at 0x000001EF23866CF0>>

# %%
#with setters
class ATM:
    def __init__(self,balance):
        self.__balance=balance

    def get_age(self):
        return self.get_balance
    
    def set_age(self,age):
        if age >0:
            self.age=age
        else:
            print("age cannot be negative")

bank1=ATM(10000)
print(bank1.get_age)
bank1.set_age(20000)
print(bank1.set_age)
# Out:
# <bound method ATM.get_age of <__main__.ATM object at 0x0000017F51A663C0>>
# <bound method ATM.set_age of <__main__.ATM object at 0x0000017F51A663C0>>
