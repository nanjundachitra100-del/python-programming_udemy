# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets

#importing the iris dataset
iris=datasets.load_iris()

# %%
iris_data=pd.data(iris.data)
iris_data
