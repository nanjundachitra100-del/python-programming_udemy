# %%
import logging

logging.basicConfig(
     filename="app.log",
    filemode="w",
    level=logging.DEBUG,
    force=True
)

logging.debug("DEBUG")
logging.info("INFO")
logging.warning("WARNING")
logging.error("ERROR")
logging.critical("CRITICAL")
# Out:
# DEBUG:root:DEBUG
# INFO:root:INFO
# WARNING:root:WARNING
# ERROR:root:ERROR
# CRITICAL:root:CRITICAL
