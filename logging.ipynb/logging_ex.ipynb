# %%
import logging

logging.basicConfig(
    filename="app.log",
    filemode="w",
    level=logging.INFO)

marks=67
if marks>45 :
    logging.info("pass")
else:
    logging.info("fail")
# Out:
# INFO:root:pass

# %%
import logging

logging.basicConfig(level=logging.WARNING)

battery = 15

if battery < 20:
    logging.warning("Battery is low. Please charge soon.")

print("Phone is still working.")
# Out:
# WARNING:root:Battery is low. Please charge soon.
# Phone is still working.
